# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.kinopoisk.ru/top/navigator/'

# %%
base_url = 'https://www.kinopoisk.ru'

# %%
movie_data = {
    'name' : 'string',
    'kinopoisk_rating' : 'float',
    'year' : 'string',
    'country' : 'string',
    'director' : 'string',
    'genre' : 'string',
    'actors': 'list',
    'poster' : 'url to image',
    'description' : 'string',
    'world_premiere' : 'date',
    'budget' : 'int',
    'fees_in_usa' : 'int',
    'fees_in_world' : 'int'
}

# %%
data = []
kinopoisk_rating = []

# %%
s = BeautifulSoup(requests.get(kinopoisk_pages[0]).content)
s = s.find('div', id='itemList')
s.find_all('div', attrs={'class': 'item _NO_HIGHLIGHT_'})
# Out:
# [<div class="item _NO_HIGHLIGHT_" id="tr_1252447">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1252447/"><img alt="Лорды раздевалки  (видео) (Lords of the Lockerroom1999)" class="flap_img" src="https://st.kp.yandex.net/images/no-poster.gif" title="/images/no-poster.gif"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1252447"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1252447/">Лорды раздевалки  (видео)</a> <span>Lords of the Lockerroom (1999) <nobr>105 мин.</nobr></span></div>
#  <span class="gray_text">
#           США,
#           <i>реж. <a class="lined" href="/name/3978602/">Мэттью Мур</a></i><br/>
#           (для взрослых, спорт)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/1245312/">Ник Стил</a>, <a class="lined" href="/name/3981260/">Ван Даркхолм</a>, <a class="lined" href="/film/1252447/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1252447" data-title="Лорды раздевалки  (видео)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1252447" value="9.392"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1252447",
#               rating:9.392,
#
#               guest:true,
#
#
#               filmId:1252447,
#               filmName:'Лорды раздевалки'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.392 <span>(1 645)</span></span></div>
#  <div class="imdb">IMDb: 9.10<span>50</span></div>
#  <div class="myVote" id="user_vote_1252447" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1252447" style="z-index:1000;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1309325">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1309325/"><img alt="Космос  (сериал) (2019 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1309325.jpg" title="/images/sm_film/1309325.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1309325"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1309325/">Космос  (сериал)</a> <span> (2019 – ...) </span></div>
#  <span class="gray_text">
#           США
#           <br/>
#           (документальный)
#        </span>
#  <span class="gray_text"></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1309325" data-title="Космос  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1309325" value="9.329"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1309325",
#               rating:9.329,
#
#               guest:true,
#
#
#               filmId:1309325,
#               filmName:'Космос'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.329 <span>(5 064)</span></span></div>
#  <div class="myVote" id="user_vote_1309325" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1309325" style="z-index:999;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1043658">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1043658/"><img alt="Шоу Грязного Фрэнка  (сериал) (The Filthy Frank Show2011 – 2017)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1043658.jpg" title="/images/sm_film/1043658.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1043658"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  <div class="flag flag9" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/9/" title="Япония"></a>
#  </div>
#  <div class="flag flag25" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/25/" title="Австралия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1043658/">Шоу Грязного Фрэнка  (сериал)</a> <span>The Filthy Frank Show (2011 – 2017) <nobr>12 мин.</nobr></span></div>
#  <span class="gray_text">
#           США...
#           <i>реж. <a class="lined" href="/name/4043243/">Джоджи</a>...</i><br/>
#           (фэнтези, комедия, музыка)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/4043243/">Джоджи</a>, <a class="lined" href="/name/4713309/">Artemis Holdenberry</a>, <a class="lined" href="/film/1043658/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1043658" data-title="Шоу Грязного Фрэнка  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1043658" value="9.307"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1043658",
#               rating:9.307,
#
#               guest:true,
#
#
#               filmId:1043658,
#               filmName:'Шоу Грязного Фрэнка'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.307 <span>(603)</span></span></div>
#  <div class="imdb">IMDb: 9.40<span>32 734</span></div>
#  <div class="myVote" id="user_vote_1043658" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1043658" style="z-index:998;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_77044">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/77044/"><img alt="Друзья  (сериал) (Friends1994 – 2004)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/77044.jpg" title="/images/sm_film/77044.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="77044"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/77044/">Друзья  (сериал)</a> <span>Friends (1994 – 2004) <nobr>22 мин.</nobr></span></div>
#  <span class="gray_text">
#           США,
#           <i>реж. <a class="lined" href="/name/26471/">Гари Хэлворсон</a>...</i><br/>
#           (комедия, мелодрама)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/21444/">Дженнифер Энистон</a>, <a class="lined" href="/name/8446/">Кортни Кокс</a>, <a class="lined" href="/film/77044/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="77044" data-title="Друзья  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_77044" value="9.246"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_77044",
#               rating:9.246,
#
#               guest:true,
#
#
#               filmId:77044,
#               filmName:'Друзья'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.246 <span>(413 542)</span></span></div>
#  <div class="imdb">IMDb: 8.80<span>902 012</span></div>
#  <div class="myVote" id="user_vote_77044" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_77044" style="z-index:997;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1003587">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1003587/"><img alt="Гамильтон (Hamilton2015)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1003587.jpg" title="/images/sm_film/1003587.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1003587"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1003587/">Гамильтон</a> <span>Hamilton (2015) <nobr>150 мин.</nobr></span></div>
#  <span class="gray_text">
#           США,
#           <i>реж. <a class="lined" href="/name/2702754/">Томас Каил</a></i><br/>
#           (мюзикл)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/1308120/">Лин-Мануэль Миранда</a>, <a class="lined" href="/name/1131675/">Лесли Одом мл.</a>, <a class="lined" href="/film/1003587/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1003587" data-title="Гамильтон" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1003587" value="9.239"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1003587",
#               rating:9.239,
#
#               guest:true,
#
#
#               filmId:1003587,
#               filmName:'Гамильтон'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.239 <span>(1 661)</span></span></div>
#  <div class="myVote" id="user_vote_1003587" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1003587" style="z-index:996;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_972889">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/972889/"><img alt="BadComedian  (сериал) (2011 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/no-poster.gif" title="/images/no-poster.gif"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="972889"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/972889/">BadComedian  (сериал)</a> <span> (2011 – ...) </span></div>
#  <span class="gray_text">
#           Россия,
#           <i>реж. <a class="lined" href="/name/3697675/">Евгений Баженов</a></i><br/>
#           (комедия)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/3697675/">Евгений Баженов</a>, <a class="lined" href="/name/2964781/">Руслан Габидуллин</a>, <a class="lined" href="/film/972889/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="972889" data-title="BadComedian  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_972889" value="9.201"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_972889",
#               rating:9.201,
#
#               guest:true,
#
#
#               filmId:972889,
#               filmName:'BadComedian'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.201 <span>(32 506)</span></span></div>
#  <div class="imdb">IMDb: 7.70<span>763</span></div>
#  <div class="myVote" id="user_vote_972889" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_972889" style="z-index:995;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_674243">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/674243/"><img alt="Счастливые люди  (мини-сериал) (2008)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/674243.jpg" title="/images/sm_film/674243.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="674243"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/674243/">Счастливые люди  (мини-сериал)</a> <span> (2008) <nobr>55 мин.</nobr></span></div>
#  <span class="gray_text">
#           Россия,
#           <i>реж. <a class="lined" href="/name/2219115/">Дмитрий Васюков</a></i><br/>
#           (документальный)
#        </span>
#  <span class="gray_text"></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="674243" data-title="Счастливые люди  (мини-сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_674243" value="9.184"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_674243",
#               rating:9.184,
#
#               guest:true,
#
#
#               filmId:674243,
#               filmName:'Счастливые люди'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.184 <span>(7 743)</span></span></div>
#  <div class="imdb">IMDb: 8.80<span>114</span></div>
#  <div class="myVote" id="user_vote_674243" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_674243" style="z-index:994;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1007472">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1007472/"><img alt="Планета Земля 2  (мини-сериал) (Planet Earth II2016)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1007472.jpg" title="/images/sm_film/1007472.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1007472"></div>
#  </div>
#  <div class="flags"> <div class="flag flag11" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/11/" title="Великобритания"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1007472/">Планета Земля 2  (мини-сериал)</a> <span>Planet Earth II (2016) <nobr>298 мин.</nobr></span></div>
#  <span class="gray_text">
#           Великобритания,
#           <i>реж. <a class="lined" href="/name/3272527/">Джастин Андерсон</a>...</i><br/>
#           (документальный)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/434946/">Дэвид Аттенборо</a>, <a class="lined" href="/film/1007472/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1007472" data-title="Планета Земля 2  (мини-сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1007472" value="9.175"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1007472",
#               rating:9.175,
#
#               guest:true,
#
#
#               filmId:1007472,
#               filmName:'Планета Земля 2'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.175 <span>(7 616)</span></span></div>
#  <div class="imdb">IMDb: 9.50<span>105 188</span></div>
#  <div class="myVote" id="user_vote_1007472" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1007472" style="z-index:993;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_2500772">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/2500772/"><img alt="Жизнь человека. Последнее интервью (2020)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/2500772.jpg" title="/images/sm_film/2500772.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="2500772"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/2500772/">Жизнь человека. Последнее интервью</a> <span> (2020) </span></div>
#  <span class="gray_text">
#           Россия,
#           <i>реж. <a class="lined" href="/name/6304340/">Сергей Карпов</a></i><br/>
#           (документальный)
#        </span>
#  <span class="gray_text"></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="2500772" data-title="Жизнь человека. Последнее интервью" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_2500772" value="9.173"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_2500772",
#               rating:9.173,
#
#               guest:true,
#
#
#               filmId:2500772,
#               filmName:'Жизнь человека. Последнее интервью'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.173 <span>(4 440)</span></span></div>
#  <div class="myVote" id="user_vote_2500772" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_2500772" style="z-index:992;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1282979">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1282979/"><img alt="LEGO Ниндзяго  (сериал) (Ninjago2019 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1282979.jpg" title="/images/sm_film/1282979.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1282979"></div>
#  </div>
#  <div class="flags"> <div class="flag flag6" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/6/" title="Канада"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1282979/">LEGO Ниндзяго  (сериал)</a> <span>Ninjago (2019 – ...) <nobr>11 мин.</nobr></span></div>
#  <span class="gray_text">
#           Канада,
#           <i>реж. <a class="lined" href="/name/863042/">Рич Джонсон</a>...</i><br/>
#           (мультфильм, боевик, детский...)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/1690958/">Келли Мецгер</a>, <a class="lined" href="/name/554914/">Майкл Адамуэйт</a>, <a class="lined" href="/film/1282979/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1282979" data-title="LEGO Ниндзяго  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1282979" value="9.168"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1282979",
#               rating:9.168,
#
#               guest:true,
#
#
#               filmId:1282979,
#               filmName:'LEGO Ниндзяго'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.168 <span>(2 911)</span></span></div>
#  <div class="imdb">IMDb: 8.00<span>499</span></div>
#  <div class="myVote" id="user_vote_1282979" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1282979" style="z-index:991;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_351771">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/351771/"><img alt="Depeche Mode: Devotional  (видео) (1993)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/351771.jpg" title="/images/sm_film/351771.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="351771"></div>
#  </div>
#  <div class="flags"> <div class="flag flag11" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/11/" title="Великобритания"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/351771/">Depeche Mode: Devotional  (видео)</a> <span> (1993) <nobr>93 мин.</nobr></span></div>
#  <span class="gray_text">
#           Великобритания,
#           <i>реж. <a class="lined" href="/name/296046/">Антон Корбейн</a></i><br/>
#           (документальный, музыка, концерт)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/611410/">Depeche Mode</a>, <a class="lined" href="/name/296026/">Дэвид Гаан</a>, <a class="lined" href="/film/351771/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="351771" data-title="Depeche Mode: Devotional  (видео)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_351771" value="9.159"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_351771",
#               rating:9.159,
#
#               guest:true,
#
#
#               filmId:351771,
#               filmName:'Depeche Mode: Devotional'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.159 <span>(1 368)</span></span></div>
#  <div class="imdb">IMDb: 9.20<span>915</span></div>
#  <div class="myVote" id="user_vote_351771" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_351771" style="z-index:990;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_326">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/326/"><img alt="Побег из Шоушенка (The Shawshank Redemption1994)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/326.jpg" title="/images/sm_film/326.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="326"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/326/">Побег из Шоушенка</a> <span>The Shawshank Redemption (1994) <nobr>142 мин.</nobr></span></div>
#  <span class="gray_text">
#           США,
#           <i>реж. <a class="lined" href="/name/24262/">Фрэнк Дарабонт</a></i><br/>
#           (драма)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/7987/">Тим Роббинс</a>, <a class="lined" href="/name/6750/">Морган Фриман</a>, <a class="lined" href="/film/326/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="326" data-title="Побег из Шоушенка" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_326" value="9.109"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_326",
#               rating:9.109,
#
#               guest:true,
#
#
#               filmId:326,
#               filmName:'Побег из Шоушенка'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.109 <span>(786 329)</span></span></div>
#  <div class="imdb">IMDb: 9.30<span>2 471 103</span></div>
#  <div class="myVote" id="user_vote_326" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_326" style="z-index:989;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_988056">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/988056/"><img alt="Малышарики  (сериал) (2015 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/988056.jpg" title="/images/sm_film/988056.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="988056"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/988056/">Малышарики  (сериал)</a> <span> (2015 – ...) <nobr>5 мин.</nobr></span></div>
#  <span class="gray_text">
#           Россия,
#           <i>реж. <a class="lined" href="/name/1898907/">Марина Мошкова</a>...</i><br/>
#           (мультфильм, детский, семейный...)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/697266/">Анна Геллер</a>, <a class="lined" href="/name/4444628/">Светлана Кузнецова</a>, <a class="lined" href="/film/988056/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="988056" data-title="Малышарики  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_988056" value="9.083"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_988056",
#               rating:9.083,
#
#               guest:true,
#
#
#               filmId:988056,
#               filmName:'Малышарики'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.083 <span>(43 238)</span></span></div>
#  <div class="imdb">IMDb: 7.30<span>46</span></div>
#  <div class="myVote" id="user_vote_988056" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_988056" style="z-index:988;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1073233">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1073233/"><img alt="Голубая планета 2  (мини-сериал) (Blue Planet II2017)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1073233.jpg" title="/images/sm_film/1073233.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1073233"></div>
#  </div>
#  <div class="flags"> <div class="flag flag11" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/11/" title="Великобритания"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1073233/">Голубая планета 2  (мини-сериал)</a> <span>Blue Planet II (2017) <nobr>364 мин.</nobr></span></div>
#  <span class="gray_text">
#           Великобритания
#           <br/>
#           (документальный)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/434946/">Дэвид Аттенборо</a>, <a class="lined" href="/name/573255/">Питер Дрост</a>, <a class="lined" href="/film/1073233/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1073233" data-title="Голубая планета 2  (мини-сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1073233" value="9.076"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1073233",
#               rating:9.076,
#
#               guest:true,
#
#
#               filmId:1073233,
#               filmName:'Голубая планета 2'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.076 <span>(1 975)</span></span></div>
#  <div class="imdb">IMDb: 9.30<span>36 681</span></div>
#  <div class="myVote" id="user_vote_1073233" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1073233" style="z-index:987;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1043713">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1043713/"><img alt="Он вам не Димон  (2017)" class="flap_img" src="https://st.kp.yandex.net/images/no-poster.gif" title="/images/no-poster.gif"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1043713"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1043713/">Он вам не Димон </a> <span> (2017) <nobr>49 мин.</nobr></span></div>
#  <span class="gray_text">
#           Россия
#           <br/>
#           (документальный)
#        </span>
#  <span class="gray_text"></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1043713" data-title="Он вам не Димон " style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1043713" value="9.072"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1043713",
#               rating:9.072,
#
#               guest:true,
#
#
#               filmId:1043713,
#               filmName:'Он вам не Димон'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.072 <span>(83 813)</span></span></div>
#  <div class="imdb">IMDb: 8.90<span>3 213</span></div>
#  <div class="myVote" id="user_vote_1043713" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1043713" style="z-index:986;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1405666">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1405666/"><img alt="Убежище. Истории о выживании в Альпах  (ТВ) (Le plus beau pays du monde 32019)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1405666.jpg" title="/images/sm_film/1405666.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1405666"></div>
#  </div>
#  <div class="flags"> <div class="flag flag8" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/8/" title="Франция"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1405666/">Убежище. Истории о выживании в Альпах  (ТВ)</a> <span>Le plus beau pays du monde 3 (2019) </span></div>
#  <span class="gray_text">
#           Франция,
#           <i>реж. <a class="lined" href="/name/402826/">Фред Фюжа</a></i><br/>
#           (документальный)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/240469/">Нэйтан Уиллкокс</a>, <a class="lined" href="/name/57172/">Жерар Ланвен</a>, <a class="lined" href="/film/1405666/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1405666" data-title="Убежище. Истории о выживании в Альпах  (ТВ)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1405666" value="9.068"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1405666",
#               rating:9.068,
#
#               guest:true,
#
#
#               filmId:1405666,
#               filmName:'Убежище. Истории о выживании в Альпах'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.068 <span>(3 764)</span></span></div>
#  <div class="imdb">IMDb: 8.70<span>45</span></div>
#  <div class="myVote" id="user_vote_1405666" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1405666" style="z-index:985;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_435">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/435/"><img alt="Зеленая миля (The Green Mile1999)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/435.jpg" title="/images/sm_film/435.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="435"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/435/">Зеленая миля</a> <span>The Green Mile (1999) <nobr>189 мин.</nobr></span></div>
#  <span class="gray_text">
#           США,
#           <i>реж. <a class="lined" href="/name/24262/">Фрэнк Дарабонт</a></i><br/>
#           (фэнтези, драма, криминал...)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/9144/">Том Хэнкс</a>, <a class="lined" href="/name/12759/">Дэвид Морс</a>, <a class="lined" href="/film/435/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="435" data-title="Зеленая миля" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_435" value="9.061"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_435",
#               rating:9.061,
#
#               guest:true,
#
#
#               filmId:435,
#               filmName:'Зеленая миля'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.061 <span>(694 935)</span></span></div>
#  <div class="imdb">IMDb: 8.60<span>1 206 579</span></div>
#  <div class="myVote" id="user_vote_435" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_435" style="z-index:984;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_438301">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/438301/"><img alt="Mylène Farmer: Mylenium Tour  (видео) (2000)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/438301.jpg" title="/images/sm_film/438301.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="438301"></div>
#  </div>
#  <div class="flags"> <div class="flag flag8" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/8/" title="Франция"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/438301/">Mylène Farmer: Mylenium Tour  (видео)</a> <span> (2000) <nobr>160 мин.</nobr></span></div>
#  <span class="gray_text">
#           Франция,
#           <i>реж. <a class="lined" href="/name/465644/">Франсуа Ансс</a></i><br/>
#           (документальный, музыка, концерт)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/276258/">Милен Фармер</a>, <a class="lined" href="/name/623329/">Айван Кассар</a>, <a class="lined" href="/film/438301/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="438301" data-title="Mylène Farmer: Mylenium Tour  (видео)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_438301" value="9.061"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_438301",
#               rating:9.061,
#
#               guest:true,
#
#
#               filmId:438301,
#               filmName:'Myl&egrave;ne Farmer: Mylenium Tour'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.061 <span>(485)</span></span></div>
#  <div class="imdb">IMDb: 9.10<span>208</span></div>
#  <div class="myVote" id="user_vote_438301" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_438301" style="z-index:983;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1235081">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1235081/"><img alt="Наша планета  (мини-сериал) (Our Planet2019)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1235081.jpg" title="/images/sm_film/1235081.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1235081"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  <div class="flag flag11" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/11/" title="Великобритания"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1235081/">Наша планета  (мини-сериал)</a> <span>Our Planet (2019) <nobr>50 мин.</nobr></span></div>
#  <span class="gray_text">
#           США...
#           <i>реж. <a class="lined" href="/name/1705864/">Адам Чэпман</a>...</i><br/>
#           (документальный)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/434946/">Дэвид Аттенборо</a>, <a class="lined" href="/film/1235081/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1235081" data-title="Наша планета  (мини-сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1235081" value="9.054"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1235081",
#               rating:9.054,
#
#               guest:true,
#
#
#               filmId:1235081,
#               filmName:'Наша планета'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>9.054 <span>(3 281)</span></span></div>
#  <div class="imdb">IMDb: 9.30<span>37 760</span></div>
#  <div class="myVote" id="user_vote_1235081" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1235081" style="z-index:982;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_650479">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/650479/"><img alt="Mylène Farmer: Stade de France  (видео) (2009)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/650479.jpg" title="/images/sm_film/650479.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="650479"></div>
#  </div>
#  <div class="flags"> <div class="flag flag8" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/8/" title="Франция"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
# ...
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_448",
#               rating:8.908,
#
#               guest:true,
#
#
#               filmId:448,
#               filmName:'Форрест Гамп'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.908 <span>(636 691)</span></span></div>
#  <div class="imdb">IMDb: 8.80<span>1 910 131</span></div>
#  <div class="myVote" id="user_vote_448" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_448" style="z-index:957;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_691558">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/691558/"><img alt="Three Days Grace: Live at the Palace 2008 (2008)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/691558.jpg" title="/images/sm_film/691558.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="691558"></div>
#  </div>
#  <div class="flags"> <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/691558/">Three Days Grace: Live at the Palace 2008</a> <span> (2008) <nobr>80 мин.</nobr></span></div>
#  <span class="gray_text">
#           США,
#           <i>реж. <a class="lined" href="/name/1240472/">Майкл Драмм</a></i><br/>
#           (музыка, концерт)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/604668/">Адам Гонтье</a>, <a class="lined" href="/name/604669/">Нил Сэндерсон</a>, <a class="lined" href="/film/691558/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="691558" data-title="Three Days Grace: Live at the Palace 2008" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_691558" value="8.908"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_691558",
#               rating:8.908,
#
#               guest:true,
#
#
#               filmId:691558,
#               filmName:'Three Days Grace: Live at the Palace 2008'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.908 <span>(136)</span></span></div>
#  <div class="imdb">IMDb: 8.50<span>60</span></div>
#  <div class="myVote" id="user_vote_691558" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_691558" style="z-index:956;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1374525">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1374525/"><img alt="Джейми Оливер: Продолжаем готовить  (сериал) (Jamie: Keep Cooking and Carry On2020)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1374525.jpg" title="/images/sm_film/1374525.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1374525"></div>
#  </div>
#  <div class="flags"> <div class="flag flag11" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/11/" title="Великобритания"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1374525/">Джейми Оливер: Продолжаем готовить  (сериал)</a> <span>Jamie: Keep Cooking and Carry On (2020) <nobr>25 мин.</nobr></span></div>
#  <span class="gray_text">
#           Великобритания
#           <br/>
#           (реальное ТВ)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/1135917/">Джейми Оливер</a>, <a class="lined" href="/film/1374525/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1374525" data-title="Джейми Оливер: Продолжаем готовить  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1374525" value="8.904"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1374525",
#               rating:8.904,
#
#               guest:true,
#
#
#               filmId:1374525,
#               filmName:'Джейми Оливер: Продолжаем готовить'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.904 <span>(1 347)</span></span></div>
#  <div class="imdb">IMDb: 7.90<span>43</span></div>
#  <div class="myVote" id="user_vote_1374525" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1374525" style="z-index:955;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_4343547">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/4343547/"><img alt="Идеальная планета  (сериал) (A Perfect Planet2021)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/4343547.jpg" title="/images/sm_film/4343547.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="4343547"></div>
#  </div>
#  <div class="flags"> <div class="flag flag11" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/11/" title="Великобритания"></a>
#  </div>
#  <div class="flag flag1" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/1/" title="США"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/4343547/">Идеальная планета  (сериал)</a> <span>A Perfect Planet (2021) <nobr>245 мин.</nobr></span></div>
#  <span class="gray_text">
#           Великобритания...
#           <i>реж. <a class="lined" href="/name/3272528/">Эд Чарльз</a>...</i><br/>
#           (документальный)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/434946/">Дэвид Аттенборо</a>, <a class="lined" href="/film/4343547/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="4343547" data-title="Идеальная планета  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_4343547" value="8.899"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_4343547",
#               rating:8.899,
#
#               guest:true,
#
#
#               filmId:4343547,
#               filmName:'Идеальная планета'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.899 <span>(237)</span></span></div>
#  <div class="imdb">IMDb: 9.10<span>2 008</span></div>
#  <div class="myVote" id="user_vote_4343547" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_4343547" style="z-index:954;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_4459937">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/4459937/"><img alt="Хочу все знать!  (сериал) (2021 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/4459937.jpg" title="/images/sm_film/4459937.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="4459937"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/4459937/">Хочу все знать!  (сериал)</a> <span> (2021 – ...) <nobr>12 мин.</nobr></span></div>
#  <span class="gray_text">
#           Россия,
#           <i>реж. <a class="lined" href="/name/6500960/">Алексей Егоров</a></i><br/>
#           (документальный, детский, реальное ТВ)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/6439146/">Андрей Одинцов</a>, <a class="lined" href="/film/4459937/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="4459937" data-title="Хочу все знать!  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_4459937" value="8.896"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_4459937",
#               rating:8.896,
#
#               guest:true,
#
#
#               filmId:4459937,
#               filmName:'Хочу все знать!'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.896 <span>(4 388)</span></span></div>
#  <div class="myVote" id="user_vote_4459937" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_4459937" style="z-index:953;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_743975">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/743975/"><img alt="Романовы  (сериал) (2013)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/743975.jpg" title="/images/sm_film/743975.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="743975"></div>
#  </div>
#  <div class="flags"> <div class="flag flag2" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/2/" title="Россия"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/743975/">Романовы  (сериал)</a> <span> (2013) <nobr>60 мин.</nobr></span></div>
#  <span class="gray_text">
#           Россия,
#           <i>реж. <a class="lined" href="/name/2309190/">Максим Беспалый</a></i><br/>
#           (документальный, история)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/1427982/">Андрей Шибаршин</a>, <a class="lined" href="/name/2635993/">Александр Горелов</a>, <a class="lined" href="/film/743975/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="743975" data-title="Романовы  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_743975" value="8.895"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_743975",
#               rating:8.895,
#
#               guest:true,
#
#
#               filmId:743975,
#               filmName:'Романовы'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.895 <span>(71 301)</span></span></div>
#  <div class="imdb">IMDb: 8.30<span>298</span></div>
#  <div class="myVote" id="user_vote_743975" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_743975" style="z-index:952;"></div>
#  </div>,
#  <div class="item _NO_HIGHLIGHT_" id="tr_1189947">
#  <div class="poster_and_flags">
#  <div class="poster"><a href="/level/1/film/1189947/"><img alt="Говорящий Том и друзья  (сериал) (Talking Tom and Friends2014 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1189947.jpg" title="/images/sm_film/1189947.jpg"/></a>
#  <div class="playTrailer movie-play-trailer-button js-discovery-trailer" data-film-id="1189947"></div>
#  </div>
#  <div class="flags"> <div class="flag flag64" style="float: left; margin: 0 2px 5px 0">
#  <a href="/lists/m_act[country]/64/" title="Кипр"></a>
#  </div>
#  </div>
#  <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
#  <span align="left" style="position: relative">
#  <span style="position: absolute; z-index: 20; visibility: visible; left:0px;">
#  <span id="handler_div_recom_448"></span>
#  </span>
#  </span>
#  </td></tr></table>
#  </div>
#  <div class="info">
#  <div class="name"><a href="/level/1/film/1189947/">Говорящий Том и друзья  (сериал)</a> <span>Talking Tom and Friends (2014 – ...) <nobr>11 мин.</nobr></span></div>
#  <span class="gray_text">
#           Кипр,
#           <i>реж. <a class="lined" href="/name/1267309/">Марк МакКонвилл</a>...</i><br/>
#           (мультфильм, детский, приключения...)
#        </span>
#  <span class="gray_text"><a class="lined" href="/name/36995/">Колин Хэнкс</a>, <a class="lined" href="/name/995814/">Том Кенни</a>, <a class="lined" href="/film/1189947/cast/#actor">...</a></span>
#  <span class="gray_text"></span>
#  <div class="js-ott-widget" data-from="kp" data-kp-film-id="1189947" data-title="Говорящий Том и друзья  (сериал)" style="display: none;">
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="WidgetStars" id="film_votes_1189947" value="8.893"></div>
#  <script type="text/javascript">
#        $(function(){
#           KP.Stars.widget({
#               divcontainer:"#film_votes_1189947",
#               rating:8.893,
#
#               guest:true,
#
#
#               filmId:1189947,
#               filmName:'Говорящий Том и друзья'
#           });
#        });
#     </script>
#  <div class="numVote ratingGreenBG"><span>8.893 <span>(2 328)</span></span></div>
#  <div class="imdb">IMDb: 6.20<span>381</span></div>
#  <div class="myVote" id="user_vote_1189947" style="display: none"><p></p><!-- <a href="" class="all" style="color: #fff"></a> --></div>
#  <div class="MyKP_Folder_Select shortselect" data="film" id="MyKP_Folder_1189947" style="z-index:951;"></div>
#  </div>]

# %%
page = 'https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results'
resp = requests.get(page)
if resp.status_code != 200:
    print('1')
soup = BeautifulSoup(resp.content)
movies_div = soup.find('div', id='itemList')

# %%
from tqdm import tqdm
import time
tryies = 10
movie_urls = []
for page in kinopoisk_pages[:1]:
    for i in range(tryies):
        try:
            resp = requests.get(page)
            if resp.status_code != 200:
                break
            soup = BeautifulSoup(resp.content)
            movies_div = soup.find('div', id='itemList')
            for movie_page in movies_div.find_all('div', attrs={'class': 'item _NO_HIGHLIGHT_'}):
                movie_urls.append(base_url + mov.find_all('a')[0].get('href'))
                kinopoisk_rating.append = mov.find('div', attrs={'numVote ratingGreenBG'}).find('span').text.split()[0]
                
        except:
            print(f'Try #{i+1} not passed\nPage: {page}')
# Out:
# Try #1 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #2 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #3 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #4 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #5 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #6 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #7 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #8 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #9 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results
# Try #10 not passed
# Page: https://www.kinopoisk.ru/top/navigator/m_act[num_vote]/100/m_act[rating]/1%3A/order/rating/page/1/#results

# %%
mov.find_all('a')
# Out:
# [<a href="/level/1/film/1309325/"><img alt="Космос  (сериал) (2019 – ...)" class="flap_img" src="https://st.kp.yandex.net/images/sm_film/1309325.jpg" title="/images/sm_film/1309325.jpg"/></a>,
#  <a href="/lists/m_act[country]/1/" title="США"></a>,
#  <a href="/level/1/film/1309325/">Космос  (сериал)</a>,
#  <a class="movie-online-button movie-online-button_on_list-item js-ott-widget__button" data-from-block="navigator">
#  </a>]
